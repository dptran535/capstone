# %% [markdown]
# # Imports

# %%
import os
import gym
from stable_baselines3 import PPO, DQN, A2C, DDPG
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %% [markdown]
# # Load Environment

# %%
env_name = 'Pendulum-v0'
env = gym.make(env_name)

# %% [markdown]
# We need to examine the action space in order to determine what algorithm to use.

# %%
env.action_space
# Out:
# Box([-2.], [2.], (1,), float32)

# %% [markdown]
# # Simple Rendering

# %%
episodes = 5
for episode in range(1, episodes + 1):
    # resets state to its initial values
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        # renders the actual environment
        env.render()
        # generates random action
        action = env.action_space.sample()
        # env.step outputs 4 values that corresponds to our variables below
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# Episode:1 Score:-964.7152960205018
# Episode:2 Score:-1314.31514106845
# Episode:3 Score:-960.2553032412387
# Episode:4 Score:-1284.6480820828795
# Episode:5 Score:-920.8666316571449

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Model 1: PPO

# %%
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(env_name)
# wraps vectorized environment around env
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=100_000)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 194  |
# |    iterations      | 1    |
# |    time_elapsed    | 10   |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 2            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0031244028 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.0046      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.15e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 0.997        |
# |    value_loss           | 6.96e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 312          |
# |    iterations           | 3            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0041475245 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.0945       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.68e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00255     |
# |    std                  | 0.996        |
# |    value_loss           | 7.84e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0015387484 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0322       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.09e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00122     |
# |    std                  | 0.985        |
# |    value_loss           | 7.37e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 358          |
# |    iterations           | 5            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0023630522 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.00903      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.46e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000918    |
# |    std                  | 0.978        |
# |    value_loss           | 7.05e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 6           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.001538068 |
# |    clip_fraction        | 0.00293     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.00411     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000597   |
# |    std                  | 0.967       |
# |    value_loss           | 6.97e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 376          |
# |    iterations           | 7            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0019093058 |
# |    clip_fraction        | 0.00825      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00189      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.75e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00152     |
# |    std                  | 0.979        |
# |    value_loss           | 9.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 384          |
# |    iterations           | 8            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0045573376 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00246      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.37e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00259     |
# |    std                  | 0.963        |
# |    value_loss           | 8.71e+03     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 385        |
# |    iterations           | 9          |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00393824 |
# |    clip_fraction        | 0.019      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.00245    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.74e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00141   |
# |    std                  | 0.946      |
# |    value_loss           | 6e+03      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 10           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0011345802 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000647     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.61e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.949        |
# |    value_loss           | 5.47e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 11           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0025298696 |
# |    clip_fraction        | 0.00913      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000279     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.38e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00113     |
# |    std                  | 0.938        |
# |    value_loss           | 7.3e+03      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 12           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0023760684 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000269     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.64e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000728    |
# |    std                  | 0.943        |
# |    value_loss           | 6.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 13           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0031599007 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000164     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.27e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000681    |
# |    std                  | 0.938        |
# |    value_loss           | 4.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 14           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0014409795 |
# |    clip_fraction        | 0.00464      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 6.53e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.56e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000938    |
# |    std                  | 0.943        |
# |    value_loss           | 6.77e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 15          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004173769 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 7.3e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.75e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00154    |
# |    std                  | 0.934       |
# |    value_loss           | 5.11e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 16           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0032333604 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 6.12e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.58e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00283     |
# |    std                  | 0.944        |
# |    value_loss           | 4.85e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 410          |
# |    iterations           | 17           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0042268466 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 4.6e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.64e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.943        |
# |    value_loss           | 5.23e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 18          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006484176 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 3.99e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00511    |
# |    std                  | 0.927       |
# |    value_loss           | 3.64e+03    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 409           |
# |    iterations           | 19            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00035726602 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.34         |
# |    explained_variance   | 3.6e-05       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.59e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 0.000109      |
# |    std                  | 0.919         |
# |    value_loss           | 4.98e+03      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 20          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003170026 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 3.09e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.36e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00214    |
# |    std                  | 0.908       |
# |    value_loss           | 6.03e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 21           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0038860864 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 3.77e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00195     |
# |    std                  | 0.905        |
# |    value_loss           | 4.49e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 22           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0040718336 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 2.65e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 0.885        |
# |    value_loss           | 4.37e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 23           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0020038595 |
# |    clip_fraction        | 0.00801      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 2.29e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.97e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000776    |
# |    std                  | 0.883        |
# |    value_loss           | 4.99e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 24          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.003979765 |
# |    clip_fraction        | 0.0162      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 1.79e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.77e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00169    |
# |    std                  | 0.869       |
# |    value_loss           | 3.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 25          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.003460884 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 1.03e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0015     |
# |    std                  | 0.858       |
# |    value_loss           | 3.94e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 418          |
# |    iterations           | 26           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0037556025 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 8.05e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.44e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00177     |
# |    std                  | 0.849        |
# |    value_loss           | 4.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 27           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0042399233 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 4.23e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00309     |
# |    std                  | 0.853        |
# |    value_loss           | 3.98e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 28          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004408706 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 6.26e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00289    |
# |    std                  | 0.847       |
# |    value_loss           | 3.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 29          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004019263 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 8.17e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.04e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00303    |
# |    std                  | 0.837       |
# |    value_loss           | 4.32e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 30           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0038566384 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 4.95e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000475    |
# |    std                  | 0.835        |
# |    value_loss           | 3.62e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 31           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0043320777 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 5.36e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00207     |
# |    std                  | 0.825        |
# |    value_loss           | 3.53e+03     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 413        |
# |    iterations           | 32         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00474165 |
# |    clip_fraction        | 0.0193     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | 4.29e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.59e+03   |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.00144   |
# |    std                  | 0.809      |
# |    value_loss           | 3.18e+03   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 33           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0020668458 |
# |    clip_fraction        | 0.0202       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 4.71e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00128     |
# |    std                  | 0.794        |
# |    value_loss           | 4.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 34           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0039681373 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 2.68e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 0.804        |
# |    value_loss           | 3.96e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 35          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.003835486 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 3.28e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00149    |
# |    std                  | 0.803       |
# |    value_loss           | 3.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 36          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.002652891 |
# |    clip_fraction        | 0.0225      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.00661     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00104    |
# |    std                  | 0.806       |
# |    value_loss           | 3.59e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 37           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0041570207 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0188       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.12e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00319     |
# |    std                  | 0.799        |
# |    value_loss           | 4.48e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 38           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0035303268 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0145       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00102     |
# |    std                  | 0.808        |
# |    value_loss           | 3.47e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 39           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0019773925 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.000792     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.99e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00101     |
# |    std                  | 0.821        |
# |    value_loss           | 4.82e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 40           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0039153127 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.00416      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 0.822        |
# |    value_loss           | 4.83e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 416          |
# |    iterations           | 41           |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0025178497 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.0138       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00159     |
# |    std                  | 0.795        |
# |    value_loss           | 4.08e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 42          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004006974 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.00764     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000291   |
# |    std                  | 0.794       |
# |    value_loss           | 3.92e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 43           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0013646667 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.0432       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000759    |
# |    std                  | 0.795        |
# |    value_loss           | 3.76e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 44           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0012145344 |
# |    clip_fraction        | 0.00894      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.055        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.57e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000612    |
# |    std                  | 0.807        |
# |    value_loss           | 3.94e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 45          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.003076877 |
# |    clip_fraction        | 0.00884     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.0461      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84e+03    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000378   |
# |    std                  | 0.802       |
# |    value_loss           | 4.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 46          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.002335175 |
# |    clip_fraction        | 0.0207      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.039       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.16e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00161    |
# |    std                  | 0.79        |
# |    value_loss           | 4.15e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 47           |
# |    time_elapsed         | 227          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0017910657 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.0424       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.72e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000459    |
# |    std                  | 0.788        |
# |    value_loss           | 4.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 48           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0032027569 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75e+03     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00265     |
# |    std                  | 0.781        |
# |    value_loss           | 4.33e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 49          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004353809 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.0907      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00245    |
# |    std                  | 0.78        |
# |    value_loss           | 3.62e+03    |
# -----------------------------------------

# %%
# PPO_Path = os.path.join('Training', 'Saved Models', 'ppo_pendulum')
# model.save(PPO_Path)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines3\common\save_util.py:276: UserWarning: Path 'Training\Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %% [markdown]
# ### Evaluation

# %% [markdown]
# The mean score of -1073 doesn't seem to good. We'll traing for longer.

# %%
evaluate_policy(model, env, n_eval_episodes=10, render = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-1073.8983472109771, 74.81807268782887)

# %%
env.close()

# %% [markdown]
# ## Model 2: A2C

# %%
model2 = A2C('MlpPolicy', env, verbose = 0, tensorboard_log = log_path)
model2.learn(total_timesteps=100_000)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Not quite pleased as we had expected the reward scores to improve. We'll try a different model.

# %%
evaluate_policy(model2, env, n_eval_episodes=10, render = True)
# Out:
# (-1222.2364308070391, 142.59367841533705)

# %%
path2 = os.path.join('Training', 'Saved Models', 'a2c_pendulum')
model2.save(path2)

# %% [markdown]
# ## Model 3: DDPG

# %%
model3 = DDPG('MlpPolicy', env, verbose = 0, tensorboard_log = log_path)
model3.learn(total_timesteps=100_000)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Tremendous improvement! The Q learning perhaps is better for the continuous movement of the pendulum. We'll train some more.

# %%
evaluate_policy(model3, env, n_eval_episodes=10, render = True)
# Out:
# (-151.64272798357996, 69.64372933655484)

# %%
path1 = os.path.join('Training', 'Saved Models', 'DDPG_pend')
model3.save(path1)

# %%
env.close()

# %% [markdown]
# ## Model 4: DDPG, 500k timesteps

# %%
# %%time
model4 = DDPG('MlpPolicy', env, verbose = 0, tensorboard_log = log_path)
model4.learn(total_timesteps=500_000)
# Out:
# Wall time: 54min 38s

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Not what we had hoped but the scores don't seem too far off our previous. A deeper implementation would need to be looked at although the pendulum does stay up.

# %%
evaluate_policy(model4, env, n_eval_episodes=10, render = True)
# Out:
# (-175.39949680198916, 56.19109718256043)

# %%
env.close()

# %%
# path4 = os.path.join('Training', 'Saved Models', 'ddpg_pendulum500k')
# model4.save(path4)

# %%
# path2 = os.path.join('Training', 'Saved Models', 'DDPG_pend_500k')
# model4.save(path2)
